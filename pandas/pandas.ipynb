# %%
import pandas as pd 
import numpy as np

# %%
s = pd.Series([10,20,30,40])
print(s)
print(s[0])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 10

# %%
s = pd.Series([100,200,300], index=["a","b","c"])
print(s)
print(s["b"])
# Out:
# a    100
# b    200
# c    300
# dtype: int64
# 200

# %%
data = {
    "Math": 90,
    "Science": 85,
    "English": 88
}

s = pd.Series(data)
print(s)
# Out:
# Math       90
# Science    85
# English    88
# dtype: int64

# %%
data = {
    "Name": ["Omer", "Ali", "Sara"],
    "Age": [20,21,22],
    "City": ["Hyderabad", "Delhi", "Mumbai"]
}

df = pd.DataFrame(data)
print(df)
print(df["Name"])
print(df[["Name", "City"]])
# Out:
#    Name  Age       City
# 0  Omer   20  Hyderabad
# 1   Ali   21      Delhi
# 2  Sara   22     Mumbai
# 0    Omer
# 1     Ali
# 2    Sara
# Name: Name, dtype: str
#    Name       City
# 0  Omer  Hyderabad
# 1   Ali      Delhi
# 2  Sara     Mumbai

# %%
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
# (151, 2)
# Index(['Name', 'Age'], dtype='str')
# Name    str
# Age     str
# dtype: object

# %%
arr = np.array([1,2,3,4])
s = pd.Series(arr)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# df = pd.read_csv("students.csv", sep=";")
df = pd.read_csv("students.csv", header=None)
# print(df)
df = pd.read_csv("students.csv", header=None, names=["Name", "Age"])
print(df)
# Out:
#                              Name            Age
# Name             Marks       City  Mobile Number
# Rajeshwari S.    85     Ahmedabad     8917005441
# Siddharth Jain   85          Pune     9761029547
# Divya Reddy      53         Delhi     8313388962
# Deepika Padukone 65         Delhi     6952192084
# ...                           ...            ...
# Advait Nair      76       Lucknow     8953905891
# Sameer Ansari    89       Lucknow     8913351509
# Amitabh Tiwari   51        Mumbai     6722914894
# Ishani Kapoor    58       Kolkata     8586001078
# Vanya Patil      46     Hyderabad     6179332277
#
# [151 rows x 2 columns]

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
print(df.head())
# Out:
#                              Name            Age
# Name             Marks       City  Mobile Number
# Rajeshwari S.    85     Ahmedabad     8917005441
# Siddharth Jain   85          Pune     9761029547
# Divya Reddy      53         Delhi     8313388962
# Deepika Padukone 65         Delhi     6952192084

# %%
df = pd.read_csv("students.csv", sep=";")
print(df)
# Out:
#              Name,Marks,City,Mobile Number
# 0    Rajeshwari S.,85,Ahmedabad,8917005441
# 1        Siddharth Jain,85,Pune,9761029547
# 2          Divya Reddy,53,Delhi,8313388962
# 3     Deepika Padukone,65,Delhi,6952192084
# 4          Sunita Devi,84,Delhi,9963343358
# ..                                     ...
# 145      Advait Nair,76,Lucknow,8953905891
# 146    Sameer Ansari,89,Lucknow,8913351509
# 147    Amitabh Tiwari,51,Mumbai,6722914894
# 148    Ishani Kapoor,58,Kolkata,8586001078
# 149    Vanya Patil,46,Hyderabad,6179332277
#
# [150 rows x 1 columns]

# %%
df = pd.read_csv("students.csv", header=None)
print(df)
# Out:
#                     0      1          2              3
# 0                Name  Marks       City  Mobile Number
# 1       Rajeshwari S.     85  Ahmedabad     8917005441
# 2      Siddharth Jain     85       Pune     9761029547
# 3         Divya Reddy     53      Delhi     8313388962
# 4    Deepika Padukone     65      Delhi     6952192084
# ..                ...    ...        ...            ...
# 146       Advait Nair     76    Lucknow     8953905891
# 147     Sameer Ansari     89    Lucknow     8913351509
# 148    Amitabh Tiwari     51     Mumbai     6722914894
# 149     Ishani Kapoor     58    Kolkata     8586001078
# 150       Vanya Patil     46  Hyderabad     6179332277
#
# [151 rows x 4 columns]

# %%
df = pd.read_csv("students.csv", header=None, names=["name", "city"])
print(df)
# Out:
#                              name           city
# Name             Marks       City  Mobile Number
# Rajeshwari S.    85     Ahmedabad     8917005441
# Siddharth Jain   85          Pune     9761029547
# Divya Reddy      53         Delhi     8313388962
# Deepika Padukone 65         Delhi     6952192084
# ...                           ...            ...
# Advait Nair      76       Lucknow     8953905891
# Sameer Ansari    89       Lucknow     8913351509
# Amitabh Tiwari   51        Mumbai     6722914894
# Ishani Kapoor    58       Kolkata     8586001078
# Vanya Patil      46     Hyderabad     6179332277
#
# [151 rows x 2 columns]

# %%
df = pd.read_csv("students.csv", index_col="id")

print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df = pd.read_csv("students.csv", index_col="id")
#       3 print(df)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/readers.py:306, in _read(filepath_or_buffer, kwds)
#     303     return parser
#     305 with parser:
# --> 306     return parser.read(nrows)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1947, in TextFileReader.read(self, nrows)
#    1940 nrows = validate_integer("nrows", nrows)
#    1941 try:
#    1942     # error: "ParserBase" has no attribute "read"
#    1943     (
#    1944         index,
#    1945         columns,
#    1946         col_dict,
# -> 1947     ) = self._engine.read(  # type: ignore[attr-defined]
#    1948         nrows
#    1949     )
#    1950 except Exception:
#    1951     self.close()
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:323, in CParserWrapper.read(self, nrows)
#     320     data = {k: v for k, (i, v) in zip(names, data_tups, strict=False)}
#     322     date_data = self._do_date_conversions(names, data)
# --> 323     index, column_names = self._make_index(alldata, names)
#     325 return index, column_names, date_data
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/base_parser.py:282, in ParserBase._make_index(self, alldata, columns, indexnamerow)
#     280 for idx in self.index_col:
#     281     if isinstance(idx, str):
# --> 282         raise ValueError(f"Index {idx} invalid")
#     283     to_remove.append(idx)
#     284     indexes.append(alldata[idx])
#
# ValueError: Index id invalid

# %%
df = pd.read_csv(
    "students.csv",
    usecols=["name", "city"]
)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df = pd.read_csv(
#       2     "students.csv",
#       3     usecols=["name", "city"]
#       4 )
#       5 print(df)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:137, in CParserWrapper.__init__(self, src, **kwds)
#     133 assert self.orig_names is not None
#     134 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     135     self.orig_names
#     136 ):
# --> 137     self._validate_usecols_names(usecols, self.orig_names)
#     139 if len(self.names) > len(usecols):
#     140     self.names = [
#     141         n
#     142         for i, n in enumerate(self.names)
#     143         if (i in usecols or n in usecols)
#     144     ]
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/io/parsers/base_parser.py:662, in ParserBase._validate_usecols_names(self, usecols, names)
#     660 missing = [c for c in usecols if c not in names]
#     661 if len(missing) > 0:
# --> 662     raise ValueError(
#     663         f"Usecols do not match columns, columns expected but not found: "
#     664         f"{missing}"
#     665     )
#     667 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['city', 'name']

# %%
df = pd.read_csv("students.csv", nrows=100)
print(df)
# Out:
#                 Name  Marks       City  Mobile Number
# 0      Rajeshwari S.     85  Ahmedabad     8917005441
# 1     Siddharth Jain     85       Pune     9761029547
# 2        Divya Reddy     53      Delhi     8313388962
# 3   Deepika Padukone     65      Delhi     6952192084
# 4        Sunita Devi     84      Delhi     9963343358
# ..               ...    ...        ...            ...
# 95     Rajeshwari S.     38    Kolkata     8271969648
# 96     Nikhil Saxena     72     Mumbai     9635108308
# 97         Aditi Rao     72     Mumbai     6279983046
# 98     Lakshya Joshi     87     Jaipur     6678296171
# 99        Kiran More     77  Hyderabad     9178318291
#
# [100 rows x 4 columns]

# %%
df = pd.read_csv(
    "students.csv",
    dtype={"id": int}
)
print(df)
# Out:
#                  Name  Marks       City  Mobile Number
# 0       Rajeshwari S.     85  Ahmedabad     8917005441
# 1      Siddharth Jain     85       Pune     9761029547
# 2         Divya Reddy     53      Delhi     8313388962
# 3    Deepika Padukone     65      Delhi     6952192084
# 4         Sunita Devi     84      Delhi     9963343358
# ..                ...    ...        ...            ...
# 145       Advait Nair     76    Lucknow     8953905891
# 146     Sameer Ansari     89    Lucknow     8913351509
# 147    Amitabh Tiwari     51     Mumbai     6722914894
# 148     Ishani Kapoor     58    Kolkata     8586001078
# 149       Vanya Patil     46  Hyderabad     6179332277
#
# [150 rows x 4 columns]

# %%
df = pd.read_json("data.json")
print(df)
# Out:
#    id  name   age       city  salary   department
# 0   1  Omer  20.0  Hyderabad   45000  Engineering
# 1   2   Ali  21.0     Mumbai   50000    Marketing
# 2   3  Sara   NaN      Delhi   47000           HR

# %%
df = pd.read_csv("students.csv")

# %%
print(df.head())
# Out:
#                Name  Marks       City  Mobile Number
# 0     Rajeshwari S.     85  Ahmedabad     8917005441
# 1    Siddharth Jain     85       Pune     9761029547
# 2       Divya Reddy     53      Delhi     8313388962
# 3  Deepika Padukone     65      Delhi     6952192084
# 4       Sunita Devi     84      Delhi     9963343358

# %%
print(df.head( 10))
# Out:
#                Name  Marks       City  Mobile Number
# 0     Rajeshwari S.     85  Ahmedabad     8917005441
# 1    Siddharth Jain     85       Pune     9761029547
# 2       Divya Reddy     53      Delhi     8313388962
# 3  Deepika Padukone     65      Delhi     6952192084
# 4       Sunita Devi     84      Delhi     9963343358
# 5   Priyanka Chopra     68    Chennai     8314940256
# 6     Lakshya Joshi     41    Chennai     7660145739
# 7   Chaitanya Reddy     88    Chennai     7548112481
# 8     Utkarsh Dubey     64    Kolkata     9873017012
# 9       Kavya Menon    100     Jaipur     6680221492

# %%
print(df.tail())
# Out:
#                Name  Marks       City  Mobile Number
# 145     Advait Nair     76    Lucknow     8953905891
# 146   Sameer Ansari     89    Lucknow     8913351509
# 147  Amitabh Tiwari     51     Mumbai     6722914894
# 148   Ishani Kapoor     58    Kolkata     8586001078
# 149     Vanya Patil     46  Hyderabad     6179332277

# %%
print(df.sample(3))
# Out:
#               Name  Marks     City  Mobile Number
# 96   Nikhil Saxena     72   Mumbai     9635108308
# 42    Tanya Mishra     67    Delhi     7508344009
# 123   Suresh Kumar     54  Lucknow     7578721259

# %%
print(df.shape)
# Out:
# (150, 4)

# %%
rows, cols = df.shape 
print(rows)
print(cols)
# Out:
# 150
# 4

# %%
print(df.columns)
# Out:
# Index(['Name', 'Marks', 'City', 'Mobile Number'], dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['Name', 'Marks', 'City', 'Mobile Number']

# %%
print(df.dtypes)
# Out:
# Name               str
# Marks            int64
# City               str
# Mobile Number    int64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           150 non-null    str
#  1   Marks          150 non-null    int64
#  2   City           150 non-null    str
#  3   Mobile Number  150 non-null    int64
# dtypes: int64(2), str(2)
# memory usage: 4.8 KB
# None

# %%
print(df.describe())
# Out:
#             Marks  Mobile Number
# count  150.000000   1.500000e+02
# mean    67.366667   8.092047e+09
# std     17.952367   1.208130e+09
# min     35.000000   6.114600e+09
# 25%     54.000000   6.961652e+09
# 50%     66.000000   8.228428e+09
# 75%     83.000000   9.187440e+09
# max    100.000000   9.963343e+09

# %%
print(df["City"].unique())
# Out:
# <StringArray>
# ['Ahmedabad',      'Pune',     'Delhi',   'Chennai',   'Kolkata',    'Jaipur',
#     'Mumbai', 'Bangalore', 'Hyderabad',   'Lucknow']
# Length: 10, dtype: str

# %%
print(df["City"].nunique())
# Out:
# 10

# %%
print(df["City"].value_counts())
# Out:
# City
# Delhi        22
# Mumbai       20
# Chennai      16
# Kolkata      16
# Lucknow      16
# Hyderabad    15
# Jaipur       14
# Ahmedabad    11
# Pune         11
# Bangalore     9
# Name: count, dtype: int64

# %%
print(df.memory_usage())
print(df.memory_usage(deep=True))
# Out:
# Index             132
# Name             1200
# Marks            1200
# City             1200
# Mobile Number    1200
# dtype: int64
# Index             132
# Name             9167
# Marks            1200
# City             8359
# Mobile Number    1200
# dtype: int64

# %%
data = {
    "Name": ["Omer", "Ali", "Sara", "John", "David"],
    "Age": [20, 21, 22, 23, 24],
    "Marks": [90, 85, 95, 80, 75],
    "City": ["Hyderabad", "Delhi", "Mumbai", "Delhi", "Chennai"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age  Marks       City
# 0   Omer   20     90  Hyderabad
# 1    Ali   21     85      Delhi
# 2   Sara   22     95     Mumbai
# 3   John   23     80      Delhi
# 4  David   24     75    Chennai

# %%
print(df["Name"])
print(type(df["Name"]))
# Out:
# 0     Omer
# 1      Ali
# 2     Sara
# 3     John
# 4    David
# Name: Name, dtype: str
# <class 'pandas.Series'>

# %%
print(df[["Name", "Marks"]])
# Out:
#     Name  Marks
# 0   Omer     90
# 1    Ali     85
# 2   Sara     95
# 3   John     80
# 4  David     75

# %%
print(df[0:3]
# Out:
#    Name  Age  Marks       City
# 0  Omer   20     90  Hyderabad
# 1   Ali   21     85      Delhi
# 2  Sara   22     95     Mumbai

# %%
print(df.loc[2])
print(df.loc[2,'Name'])
print(df.loc[[1,3]])
print(df.loc[1:3,['Name', 'Marks']])
# Out:
# Name       Sara
# Age          22
# Marks        95
# City     Mumbai
# Name: 2, dtype: object
# Sara
#    Name  Age  Marks   City
# 1   Ali   21     85  Delhi
# 3  John   23     80  Delhi
#    Name  Marks
# 1   Ali     85
# 2  Sara     95
# 3  John     80

# %%
print(df.iloc[2])
print(df.iloc[2,0])
print(df.iloc[1:4, 0:2])
# Out:
# Name       Sara
# Age          22
# Marks        95
# City     Mumbai
# Name: 2, dtype: object
# Sara
#    Name  Age
# 1   Ali   21
# 2  Sara   22
# 3  John   23

# %%
print(df[df['Marks'] > 85])
# Out:
#    Name  Age  Marks       City
# 0  Omer   20     90  Hyderabad
# 2  Sara   22     95     Mumbai

# %%
print(df[(df["Marks"] > 80 ) & (df["Age"] < 23)])
# Out:
#    Name  Age  Marks       City
# 0  Omer   20     90  Hyderabad
# 1   Ali   21     85      Delhi
# 2  Sara   22     95     Mumbai

# %%
print(df[(df["City"] == "Delhi") | (df["Marks"] > 90)])
# Out:
#    Name  Age  Marks    City
# 1   Ali   21     85   Delhi
# 2  Sara   22     95  Mumbai
# 3  John   23     80   Delhi

# %%
print(df[df["Marks"] > 80][["Name", "Marks"]])
# Out:
#    Name  Marks
# 0  Omer     90
# 1   Ali     85
# 2  Sara     95

# %%
print(df["City"].unique())
# Out:
# <StringArray>
# ['Hyderabad', 'Delhi', 'Mumbai', 'Chennai']
# Length: 4, dtype: str

# %%
print(df["City"].nunique())
# Out:
# 4

# %%
print(df["City"].value_counts())
# Out:
# City
# Delhi        2
# Hyderabad    1
# Mumbai       1
# Chennai      1
# Name: count, dtype: int64

# %%
data = {
    "Name": ["Omer", "Ali", "Sara", None],
    "Age": [20, np.nan, 22, 23],
    "Salary": [50000, 60000, np.nan, 70000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Name   Age   Salary
# 0  Omer  20.0  50000.0
# 1   Ali   NaN  60000.0
# 2  Sara  22.0      NaN
# 3   NaN  23.0  70000.0

# %%
print(df.isnull())
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3   True  False   False

# %%
print(df.isnull().sum())
# Out:
# Name      1
# Age       1
# Salary    1
# dtype: int64

# %%
clean_df = df.dropna()
print(clean_df)
# Out:
#    Name   Age   Salary
# 0  Omer  20.0  50000.0

# %%
print(df.dropna(axis=1))
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
mean_age = df["Age"].mean()
df["Age"] = df["Age"].fillna(mean_age)
print(df)
# Out:
#    Name        Age   Salary
# 0  Omer  20.000000  50000.0
# 1   Ali  21.666667  60000.0
# 2  Sara  22.000000      NaN
# 3   NaN  23.000000  70000.0

# %%
print(df.duplicated())
print(df.duplicated().sum())
df = df.drop_duplicates()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
# 0

# %%
print(df.dtypes)
# Out:
# Name          str
# Age       float64
# Salary    float64
# dtype: object

# %%
df['Age'] =df['Age'].astype(int)
print(df)
# Out:
#    Name  Age   Salary
# 0  Omer   20  50000.0
# 1   Ali   21  60000.0
# 2  Sara   22      NaN
# 3   NaN   23  70000.0

# %%
df["Salary"] = df["Salary"].astype(float)

# %%
df["City"] = df["City"].str.lower()
df["City"] = df["City"].str.upper()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df["City"] = df["City"].str.lower()
#       2 df["City"] = df["City"].str.upper()
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/miniconda3/envs/ds/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'City'
