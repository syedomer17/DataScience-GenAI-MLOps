# %%
import pandas as pd 
import numpy as np

# %%
data = {
    "Name": ["Alic","Bob","Charlie","David","Emma"],
    "Age": [25,30,35,40,22],
    "Score": [88,92,79,85,95]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age  Score
# 0     Alic   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95

# %%
df[df["Age"] > 30 ]
# Out:
#       Name  Age  Score
# 2  Charlie   35     79
# 3    David   40     85

# %%
df[(df["Age"] > 25) & (df["Score"] > 85)]
# Out:
#   Name  Age  Score
# 1  Bob   30     92

# %%
df[(df["Age"] < 25 ) | (df["Score"] > 90)]
# Out:
#    Name  Age  Score
# 1   Bob   30     92
# 4  Emma   22     95

# %%
df[~(df["Score"] > 85)]
# Out:
#       Name  Age  Score
# 2  Charlie   35     79
# 3    David   40     85

# %%
df[(df["Age"] > 25) & (df["Score"] > 85)]
# Out:
#   Name  Age  Score
# 1  Bob   30     92

# %%
df.query("Age > 25")
# Out:
#       Name  Age  Score
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85

# %%
df.query("Age < 35 and Score >= 85")
# Out:
#    Name  Age  Score
# 0  Alic   25     88
# 1   Bob   30     92
# 4  Emma   22     95

# %%
hold = 90
df.query("Score > @hold")
# Out:
#    Name  Age  Score
# 1   Bob   30     92
# 4  Emma   22     95

# %%
df["Name"].str.lower()
# Out:
# 0       alic
# 1        bob
# 2    charlie
# 3      david
# 4       emma
# Name: Name, dtype: str
